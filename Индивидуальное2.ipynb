# %% [markdown]
# <a href="https://colab.research.google.com/github/dzhamalovas/Osnovy_programming/blob/main/%D0%98%D0%BD%D0%B4%D0%B8%D0%B2%D0%B8%D0%B4%D1%83%D0%B0%D0%BB%D1%8C%D0%BD%D0%BE%D0%B52.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Снимок.PNG](data:image/png;base64,...)

# %%
class Goose:
  def __init__(self, name, weight):
    self.name = name
    self.weight = weight
  def feed(self):
    print("Кличка:", self.name)
    print('Вы напоили животное? ')
    self.ans = input("да/нет ")
    if self.ans == 'нет':
      print('Не забудьте напоить!')
    elif self.ans != 'да' and self.ans != 'нет':
      print('Ошибка ввода')
    self.n = float(input("Введите нормальный вес: "))
    if self.weight > self.n:
      print("Кормите меньше.")
    elif self.weight < self.n:
      print("Кормите больше!")
    print(f'Гусь {self.name} покормлен')
  def voice(self):
    print("Гусь делает га-га-га")
  def collect_eggs(self):
    print(f'Гусь {self.name} отложил яйцо')

class Cow:
  def __init__(self, name, weight):
    self.name = name
    self.weight = weight
  def feed(self):
    print("Кличка:", self.name)
    print('Вы напоили животное? ')
    self.ans = input("да/нет ")
    if self.ans == 'нет':
      print('Не забудьте напоить!')
    elif self.ans != 'да' and self.ans != 'нет':
      print('Ошибка ввода')
    self.n = float(input("Введите нормальный вес: "))
    if self.weight > self.n:
      print("Кормите меньше.")
    elif self.weight < self.n:
      print("Кормите больше!")
    print(f'Корова {self.name} покормлена')
  def voice(self):
    print("Корова делает мууу")
  def milk(self):
    print('Подоили ли вы корову?')
    self.ans = input("да/нет ")
    if self.ans == 'да':
      print('Корова подоена')
    elif self.ans == 'нет':
      print('Необходимо подоить')
    else:
      print('Ошибка ввода')

class Sheep:
  def __init__(self, name, weight):
    self.name = name
    self.weight = weight
  def feed(self):
    print("Кличка:", self.name)
    print('Вы напоили животное? ')
    self.ans = input("да/нет ")
    if self.ans == 'нет':
      print('Не забудьте напоить!')
    elif self.ans != 'да' and self.ans != 'нет':
      print('Ошибка ввода')
    self.n = float(input("Введите нормальный вес: "))
    if self.weight > self.n:
      print("Кормите меньше.")
    elif self.weight < self.n:
      print("Кормите больше!")
    print(f'Овца {self.name} покормлен')
  def voice(self):
    print("Овца делает меее")
  def cut(self):
    print('Подстригли ли вы козу?')
    self.ans = input("да/нет ")
    if self.ans == 'да':
      print('Коза подстрижена')
    elif self.ans == 'нет':
      print('Необходимо подстричь')
    else:
      print('Ошибка ввода')
  
class Chicken:
  def __init__(self, name, weight):
    self.name = name
    self.weight = weight
  def feed(self):
    print("Кличка:", self.name)
    print('Вы напоили животное? ')
    self.ans = input("да/нет ")
    if self.ans == 'нет':
      print('Не забудьте напоить!')
    elif self.ans != 'да' and self.ans != 'нет':
      print('Ошибка ввода')
    self.n = float(input("Введите нормальный вес: "))
    if self.weight > self.n:
      print("Кормите меньше.")
    elif self.weight < self.n:
      print("Кормите больше!")
    print(f'Курица {self.name} покормлена')
  def voice(self):
    print("Курица делает ко-ко-ко")
  def collect_eggs(self):
    print(f'Курица {self.name} отложила яйцо')

class Goat:
  def __init__(self, name, weight):
    self.name = name
    self.weight = weight
  def feed(self):
    print("Кличка:", self.name)
    print('Вы напоили животное? ')
    self.ans = input("да/нет ")
    if self.ans == 'нет':
      print('Не забудьте напоить!')
    elif self.ans != 'да' and self.ans != 'нет':
      print('Ошибка ввода')
    self.n = float(input("Введите нормальный вес: "))
    if self.weight > self.n:
      print("Кормите меньше.")
    elif self.weight < self.n:
      print("Кормите больше!")
    print(f'Коза {self.name} покормлена')
  def voice(self):
    print("Коза делает беее")
  def milk(self):
    print('Подоили ли вы козу?')
    self.ans = input("да/нет ")
    if self.ans == 'да':
      print('Коза подоена')
    elif self.ans == 'нет':
      print('Необходимо подоить')
    else:
      print('Ошибка ввода')

class Duck:
  def __init__(self, name, weight):
    self.name = name
    self.weight = weight
  def feed(self):
    print("Кличка:", self.name)
    print('Вы напоили животное? ')
    self.ans = input("да/нет ")
    if self.ans == 'нет':
      print('Не забудьте напоить!')
    elif self.ans != 'да' and self.ans != 'нет':
      print('Ошибка ввода')
    self.n = float(input("Введите нормальный вес: "))
    if self.weight > self.n:
      print("Кормите меньше.")
    elif self.weight < self.n:
      print("Кормите больше!")
    print(f'Утка {self.name} покормлена')
  def voice(self):
    print("Утка делает кря-кря")
  def collect_eggs(self):
    print(f'Утка {self.name} отложила яйцо')

# %%
grey_goose = Goose("Серый", 3)
grey_goose.feed()
grey_goose.voice()
grey_goose.collect_eggs()
print('')

white_goose = Goose("Белый", 4)
white_goose.feed()
white_goose.voice()
white_goose.collect_eggs()
print('')

manka_cow = Cow("Манька", 500)
manka_cow.feed()
manka_cow.voice()
manka_cow.milk()
print('')

bar_sheep = Sheep("Барашек", 70)
bar_sheep.feed()
bar_sheep.voice()
bar_sheep.cut()
print('')

curly_sheep = Sheep("Kудрявый", 80)
curly_sheep.feed()
curly_sheep.voice()
curly_sheep.cut()
print('')

ko_ko_chicken = Chicken("Ко-ко", 1.5)
ko_ko_chicken.feed()
ko_ko_chicken.voice()
ko_ko_chicken.collect_eggs()
print('')

kukareku_chicken = Chicken("Кукареку", 2)
kukareku_chicken.feed()
kukareku_chicken.voice()
kukareku_chicken.collect_eggs()
print('')

horns_goat = Goat("Рогa", 45)
horns_goat.feed()
horns_goat.voice()
horns_goat.milk()
print('')

hoof_goat = Goat("Kопытa", 50)
hoof_goat.feed()
hoof_goat.voice()
hoof_goat.milk()
print('')

quack_duck = Duck("Kряквa", 2.5)
quack_duck.feed()
quack_duck.voice()
quack_duck.collect_eggs()
print('')


total_weight = grey_goose.weight + white_goose.weight + manka_cow.weight + bar_sheep.weight + curly_sheep.weight + ko_ko_chicken.weight + kukareku_chicken.weight + horns_goat.weight + hoof_goat.weight + quack_duck.weight
print(f"Общий вес всех животных: {total_weight}")
# Out:
# Кличка: Серый
# Вы напоили животное?
# да/нет да
# Введите нормальный вес: 6
# Кормите больше!
# Гусь Серый покормлен
# Гусь делает га-га-га
# Гусь Серый отложил яйцо
#
# Кличка: Белый
# Вы напоили животное?
# да/нет нет
# Не забудьте напоить!
# Введите нормальный вес: 4
# Гусь Белый покормлен
# Гусь делает га-га-га
# Гусь Белый отложил яйцо
#
# Кличка: Манька
# Вы напоили животное?
# да/нет да
# Введите нормальный вес: 570
# Кормите больше!
# Корова Манька покормлена
# Корова делает мууу
# Подоили ли вы корову?
# да/нет да
# Корова подоена
#
# Кличка: Барашек
# Вы напоили животное?
# да/нет да
# Введите нормальный вес: 34
# Кормите меньше.
# Овца Барашек покормлен
# Овца делает меее
# Подстригли ли вы козу?
# да/нет да
# Коза подстрижена
#
# Кличка: Kудрявый
# Вы напоили животное?
# да/нет да
# Введите нормальный вес: 45
# Кормите меньше.
# Овца Kудрявый покормлен
# Овца делает меее
# Подстригли ли вы козу?
# да/нет да
# Коза подстрижена
#
# Кличка: Ко-ко
# Вы напоили животное?
# ...

# %% [markdown]
# ## Без учета количества еды и воды

# %%
class Goose:
  def __init__(self, name, weight):
    self.name = name
    self.weight = weight
  def feed(self):
    print(f'Гусь {self.name} покормлен')
  def voice(self):
    print("Гусь делает га-га-га")
  def collect_eggs(self):
    print(f'Гусь {self.name} отложил яйцо')

class Cow:
  def __init__(self, name, weight):
    self.name = name
    self.weight = weight
  def feed(self):
    print(f'Корова {self.name} покормлена')
  def voice(self):
    print("Корова делает мууу")
  def milk(self):
    print('Подоили ли вы корову?')
    self.ans = input("да/нет ")
    if self.ans == 'да':
      print('Корова подоена')
    elif self.ans == 'нет':
      print('Необходимо подоить')
    else:
      print('Ошибка ввода')

class Sheep:
  def __init__(self, name, weight):
    self.name = name
    self.weight = weight
  def feed(self):
    print(f'Овца {self.name} покормлен')
  def voice(self):
    print("Овца делает меее")
  def cut(self):
    print('Подстригли ли вы козу?')
    self.ans = input("да/нет ")
    if self.ans == 'да':
      print('Коза подстрижена')
    elif self.ans == 'нет':
      print('Необходимо подстричь')
    else:
      print('Ошибка ввода')
  
class Chicken:
  def __init__(self, name, weight):
    self.name = name
    self.weight = weight
  def feed(self):
    print(f'Курица {self.name} покормлена')
  def voice(self):
    print("Курица делает ко-ко-ко")
  def collect_eggs(self):
    print(f'Курица {self.name} отложила яйцо')

class Goat:
  def __init__(self, name, weight):
    self.name = name
    self.weight = weight
  def feed(self):
    print(f'Коза {self.name} покормлена')
  def voice(self):
    print("Коза делает беее")
  def milk(self):
    print('Подоили ли вы козу?')
    self.ans = input("да/нет ")
    if self.ans == 'да':
      print('Коза подоена')
    elif self.ans == 'нет':
      print('Необходимо подоить')
    else:
      print('Ошибка ввода')

class Duck:
  def __init__(self, name, weight):
    self.name = name
    self.weight = weight
  def feed(self):
    print(f'Утка {self.name} покормлена')
  def voice(self):
    print("Утка делает кря-кря")
  def collect_eggs(self):
    print(f'Утка {self.name} отложила яйцо')

# %%
grey_goose = Goose("Серый", 3)
grey_goose.feed()
grey_goose.voice()
grey_goose.collect_eggs()
print('')

white_goose = Goose("Белый", 4)
white_goose.feed()
white_goose.voice()
white_goose.collect_eggs()
print('')

manka_cow = Cow("Манька", 500)
manka_cow.feed()
manka_cow.voice()
manka_cow.milk()
print('')

bar_sheep = Sheep("Барашек", 70)
bar_sheep.feed()
bar_sheep.voice()
bar_sheep.cut()
print('')

curly_sheep = Sheep("Kудрявый", 80)
curly_sheep.feed()
curly_sheep.voice()
curly_sheep.cut()
print('')

ko_ko_chicken = Chicken("Ко-ко", 1.5)
ko_ko_chicken.feed()
ko_ko_chicken.voice()
ko_ko_chicken.collect_eggs()
print('')

kukareku_chicken = Chicken("Кукареку", 2)
kukareku_chicken.feed()
kukareku_chicken.voice()
kukareku_chicken.collect_eggs()
print('')

horns_goat = Goat("Рогa", 45)
horns_goat.feed()
horns_goat.voice()
horns_goat.milk()
print('')

hoof_goat = Goat("Kопытa", 50)
hoof_goat.feed()
hoof_goat.voice()
hoof_goat.milk()
print('')

quack_duck = Duck("Kряквa", 2.5)
quack_duck.feed()
quack_duck.voice()
quack_duck.collect_eggs()
print('')


total_weight = grey_goose.weight + white_goose.weight + manka_cow.weight + bar_sheep.weight + curly_sheep.weight + ko_ko_chicken.weight + kukareku_chicken.weight + horns_goat.weight + hoof_goat.weight + quack_duck.weight
print(f"Общий вес всех животных: {total_weight}")
# Out:
# Гусь Серый покормлен
# Гусь делает га-га-га
# Гусь Серый отложил яйцо
#
# Гусь Белый покормлен
# Гусь делает га-га-га
# Гусь Белый отложил яйцо
#
# Корова Манька покормлена
# Корова делает мууу
# Подоили ли вы корову?
# да/нет да
# Корова подоена
#
# Овца Барашек покормлен
# Овца делает меее
# Подстригли ли вы козу?
# да/нет нет
# Необходимо подстричь
#
# Овца Kудрявый покормлен
# Овца делает меее
# Подстригли ли вы козу?
# да/нет да
# Коза подстрижена
#
# Курица Ко-ко покормлена
# Курица делает ко-ко-ко
# Курица Ко-ко отложила яйцо
#
# Курица Кукареку покормлена
# Курица делает ко-ко-ко
# Курица Кукареку отложила яйцо
#
# Коза Рогa покормлена
# Коза делает беее
# Подоили ли вы козу?
# да/нет нет
# Необходимо подоить
#
# Коза Kопытa покормлена
# Коза делает беее
# Подоили ли вы козу?
# да/нет да
# Коза подоена
#
# Утка Kряквa покормлена
# Утка делает кря-кря
# УТка Kряквa отложила яйцо
#
# Общий вес всех животных: 758.0
